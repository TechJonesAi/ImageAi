# %% [markdown]
# <a href="https://colab.research.google.com/github/TechJonesAi/ImageAi/blob/master/Four_Flowers_Classsifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click the button to the left To initialise
import warnings
warnings.filterwarnings('ignore')
from fastai.vision import *
import skimage
import matplotlib.pyplot as plt
# %matplotlib inline
file_id = "10d_d2E5Ml-gSfrG_rmBNEzgFOd7BSX__" # replace with your ID
# !gdown https://drive.google.com/uc?id={file_id}
my_model = load_learner("/content") 
from google.colab import files
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10d_d2E5Ml-gSfrG_rmBNEzgFOd7BSX__
# To: /content/export.pkl
# 87.4MB [00:01, 61.7MB/s]

# %% [markdown]
# **Upload your Picture of Aconitum, Daffodil, Hibiscus or Roses Here**

# %%
#@title NOW RUN THIS CELL TO Upload Your picture
files.upload()
# Out:
#      <input type="file" id="files-b244204c-a3b7-45c1-a7bb-1ee986ff18a4" name="files[]" multiple disabled />
#      <output id="result-b244204c-a3b7-45c1-a7bb-1ee986ff18a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EJJN9R8.jpg to EJJN9R8.jpg
# ...

# %%
#@title **NOW RUN THIS CELL TO PREDICT YOUR PICTURE**
import subprocess
latest_img_name = subprocess.getoutput("ls -Art | tail -n 1 ")
print(latest_img_name)
img = open_image(f'/content/{latest_img_name}')
img
pred_class,_,_=my_model.predict(img)
print(pred_class)
# Out:
# EJJN9R8.jpg
# Daffodil
